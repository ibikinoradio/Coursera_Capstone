# %% [markdown]
# # **Segmenting and Clustering Neighborhoods in Toronto**
#
# ####IBM Data Science Capstone project, Peer-graded assignment
#
# *Author: E. Malamura*
#
# *Publication date:*

# %% [markdown]
# #### **Task Description**
#
# In this assignment, you will be required to explore, segment, and cluster the neighborhoods in the city of Toronto based on the postalcode and borough information.. However, unlike New York, the neighborhood data is not readily available on the internet. What is interesting about the field of data science is that each project can be challenging in its unique way, so you need to learn to be agile and refine the skill to learn new libraries and tools quickly depending on the project.
#
# For the Toronto neighborhood data, a Wikipedia page exists that has all the information we need to explore and cluster the neighborhoods in Toronto. You will be required to scrape the Wikipedia page and wrangle the data, clean it, and then read it into a pandas  dataframe so that it is in a structured format like the New York dataset.
#
# Once the data is in a structured format, you can replicate the analysis that we did to the New York City dataset to explore and cluster the neighborhoods in the city of Toronto.

# %% [markdown]
# # Part 1: Scraping Toronto neighborhoods data from wikipedia

# %%
import pandas as pd
import random
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
data  = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")

# %% [markdown]
# The following scraping code is copy-pasted from the Hint for this assignment.

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %% [markdown]
# As soon as the expected number of rows is not too large, I will print the entire dataframe and inspect it visually.

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#     PostalCode  ...                                       Neighborhood
# 0          M3A  ...                                          Parkwoods
# 1          M4A  ...                                   Victoria Village
# 2          M5A  ...                          Regent Park, Harbourfront
# 3          M6A  ...                   Lawrence Manor, Lawrence Heights
# 4          M7A  ...                      Ontario Provincial Government
# 5          M9A  ...                                   Islington Avenue
# 6          M1B  ...                                     Malvern, Rouge
# 7          M3B  ...                                    Don Mills North
# 8          M4B  ...                    Parkview Hill, Woodbine Gardens
# 9          M5B  ...                           Garden District, Ryerson
# 10         M6B  ...                                          Glencairn
# 11         M9B  ...  West Deane Park, Princess Gardens, Martin Grov...
# 12         M1C  ...             Rouge Hill, Port Union, Highland Creek
# 13         M3C  ...                                    Don Mills South
# 14         M4C  ...                                   Woodbine Heights
# 15         M5C  ...                                     St. James Town
# 16         M6C  ...                                 Humewood-Cedarvale
# 17         M9C  ...  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18         M1E  ...                  Guildwood, Morningside, West Hill
# 19         M4E  ...                                        The Beaches
# 20         M5E  ...                                        Berczy Park
# 21         M6E  ...                                Caledonia-Fairbanks
# 22         M1G  ...                                             Woburn
# 23         M4G  ...                                            Leaside
# 24         M5G  ...                                 Central Bay Street
# 25         M6G  ...                                           Christie
# 26         M1H  ...                                          Cedarbrae
# 27         M2H  ...                                  Hillcrest Village
# 28         M3H  ...    Bathurst Manor, Wilson Heights, Downsview North
# 29         M4H  ...                                   Thorncliffe Park
# 30         M5H  ...                           Richmond, Adelaide, King
# 31         M6H  ...                       Dufferin, Dovercourt Village
# 32         M1J  ...                                Scarborough Village
# 33         M2J  ...                       Fairview, Henry Farm, Oriole
# 34         M3J  ...                    Northwood Park, York University
# 35         M4J  ...                                 The Danforth  East
# 36         M5J  ...  Harbourfront East, Union Station, Toronto Islands
# 37         M6J  ...                           Little Portugal, Trinity
# 38         M1K  ...        Kennedy Park, Ionview, East Birchmount Park
# 39         M2K  ...                                    Bayview Village
# 40         M3K  ...                                     Downsview East
# 41         M4K  ...                       The Danforth West, Riverdale
# 42         M5K  ...           Toronto Dominion Centre, Design Exchange
# 43         M6K  ...       Brockton, Parkdale Village, Exhibition Place
# 44         M1L  ...                    Golden Mile, Clairlea, Oakridge
# 45         M2L  ...                           York Mills, Silver Hills
# 46         M3L  ...                                     Downsview West
# 47         M4L  ...                     India Bazaar, The Beaches West
# 48         M5L  ...                     Commerce Court, Victoria Hotel
# 49         M6L  ...           North Park, Maple Leaf Park, Upwood Park
# 50         M9L  ...                                      Humber Summit
# 51         M1M  ...    Cliffside, Cliffcrest, Scarborough Village West
# 52         M2M  ...                            Willowdale, Newtonbrook
# 53         M3M  ...                                  Downsview Central
# 54         M4M  ...                                    Studio District
# 55         M5M  ...                  Bedford Park, Lawrence Manor East
# 56         M6M  ...   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 57         M9M  ...                                   Humberlea, Emery
# 58         M1N  ...                        Birch Cliff, Cliffside West
# 59         M2N  ...                                   Willowdale South
# 60         M3N  ...                                Downsview Northwest
# 61         M4N  ...                                      Lawrence Park
# 62         M5N  ...                                           Roselawn
# 63         M6N  ...                      Runnymede, The Junction North
# 64         M9N  ...                                             Weston
# 65         M1P  ...  Dorset Park, Wexford Heights, Scarborough Town...
# 66         M2P  ...                                    York Mills West
# 67         M4P  ...                                   Davisville North
# 68         M5P  ...                           Forest Hill North & West
# 69         M6P  ...                      High Park, The Junction South
# 70         M9P  ...                                          Westmount
# 71         M1R  ...                                  Wexford, Maryvale
# 72         M2R  ...                                    Willowdale West
# 73         M4R  ...                                 North Toronto West
# 74         M5R  ...                The Annex, North Midtown, Yorkville
# 75         M6R  ...                             Parkdale, Roncesvalles
# 76         M7R  ...                                     Enclave of L4W
# 77         M9R  ...  Kingsview Village, St. Phillips, Martin Grove ...
# 78         M1S  ...                                          Agincourt
# 79         M4S  ...                                         Davisville
# 80         M5S  ...                     University of Toronto, Harbord
# 81         M6S  ...                                 Runnymede, Swansea
# 82         M1T  ...            Clarks Corners, Tam O'Shanter, Sullivan
# 83         M4T  ...                        Moore Park, Summerhill East
# 84         M5T  ...          Kensington Market, Chinatown, Grange Park
# 85         M1V  ...  Milliken, Agincourt North, Steeles East, L'Amo...
# 86         M4V  ...  Summerhill West, Rathnelly, South Hill, Forest...
# 87         M5V  ...  CN Tower, King and Spadina, Railway Lands, Har...
# 88         M8V  ...       New Toronto, Mimico South, Humber Bay Shores
# 89         M9V  ...  South Steeles, Silverstone, Humbergate, Jamest...
# 90         M1W  ...                      Steeles West, L'Amoreaux West
# 91         M4W  ...                                           Rosedale
# 92         M5W  ...                                     Enclave of M5E
# 93         M8W  ...                             Alderwood, Long Branch
# 94         M9W  ...  Clairville, Humberwood, Woodbine Downs, West H...
# 95         M1X  ...                                        Upper Rouge
# 96         M4X  ...                        St. James Town, Cabbagetown
# 97         M5X  ...             First Canadian Place, Underground city
# 98         M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99         M4Y  ...                               Church and Wellesley
# 100        M7Y  ...                                     Enclave of M4L
# 101        M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102        M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
print('The shape of the dataframe is:', df.shape)
# Out:
# The shape of the dataframe is: (103, 3)

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# # Part 2: Add Lattitude and Longtitude data to dataframe
#
# (the geocoder continuously returns None, I will take the coordinates data from CSV file)

# %% [markdown]
# Load csv from url to a new dataframe

# %%
df_geo = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv')
pd.set_option('display.max_rows', 10)
df_geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# Merge dataframes based on PostalCode column

# %%
df_geo.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)
df = pd.merge(df, df_geo, on='PostalCode')

del df_geo

df.head()
# Out:
#   PostalCode           Borough  ...   Latitude  Longitude
# 0        M3A        North York  ...  43.753259 -79.329656
# 1        M4A        North York  ...  43.725882 -79.315572
# 2        M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3        M6A        North York  ...  43.718518 -79.464763
# 4        M7A      Queen's Park  ...  43.662301 -79.389494
#
# [5 rows x 5 columns]

# %% [markdown]
# _______________________________________________________________________

# %% [markdown]
# # Part 3: Explore and cluster the neighborhoods in Toronto

# %% [markdown]
# Drop boroghs which don't contain 'Toronto'

# %%
df = df[df['Borough'].str.contains("Toronto")]
df.reset_index(drop=True, inplace=True)
df
# Out:
#    PostalCode                 Borough  ...   Latitude  Longitude
# 0         M5A        Downtown Toronto  ...  43.654260 -79.360636
# 1         M5B        Downtown Toronto  ...  43.657162 -79.378937
# 2         M5C        Downtown Toronto  ...  43.651494 -79.375418
# 3         M4E            East Toronto  ...  43.676357 -79.293031
# 4         M5E        Downtown Toronto  ...  43.644771 -79.373306
# ..        ...                     ...  ...        ...        ...
# 34        M5W  Downtown Toronto Stn A  ...  43.646435 -79.374846
# 35        M4X        Downtown Toronto  ...  43.667967 -79.367675
# 36        M5X        Downtown Toronto  ...  43.648429 -79.382280
# 37        M4Y        Downtown Toronto  ...  43.665860 -79.383160
# 38        M7Y   East Toronto Business  ...  43.662744 -79.321558
#
# [39 rows x 5 columns]

# %% [markdown]
# Get the coordinates of Toronto

# %%
#!pip install geopy
from geopy.geocoders import Nominatim

# %%
address = 'Toronto, OA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, OA are 43.6534817, -79.3839347.

# %% [markdown]
# Create a map of Toronto with neighborhoods superimposed on top.

# %%
import folium

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_fa5e26c939384e649da6842f443541fa%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa5e26c939384e649da6842f443541fa%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_fa5e26c939384e649da6842f443541fa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_fa5e26c939384e649da6842f443541fa%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_e3c4ec7ca16e4b1ba29f76ae3f8ba7b0%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# This is a saved screenshot of the above result for sharing on github
# ![toronto neighbourhoods](https://raw.githubusercontent.com/ibikinoradio/Coursera_Capstone/main/toronto_hoods.jpg)

# %% [markdown]
# Foursquare credentials

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# Function for exploration of a neighbourhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Enclave of M5E
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Enclave of M4L

# %% [markdown]
# Dataframe of venues

# %%
toronto_venues
# Out:
#                    Neighborhood  ...       Venue Category
# 0     Regent Park, Harbourfront  ...          Coffee Shop
# 1     Regent Park, Harbourfront  ...               Bakery
# 2     Regent Park, Harbourfront  ...  Distribution Center
# 3     Regent Park, Harbourfront  ...                  Spa
# 4     Regent Park, Harbourfront  ...           Restaurant
# ...                         ...  ...                  ...
# 1494             Enclave of M4L  ...                 Park
# 1495             Enclave of M4L  ...                  Spa
# 1496             Enclave of M4L  ...          Yoga Studio
# 1497             Enclave of M4L  ...              Butcher
# 1498             Enclave of M4L  ...           Skate Park
#
# [1499 rows x 7 columns]

# %% [markdown]
# Number of venues in each neighbourhood

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Berczy Park                                                            48  ...              48
# Brockton, Parkdale Village, Exhibition Place                           23  ...              23
# CN Tower, King and Spadina, Railway Lands, Harb...                     18  ...              18
# Central Bay Street                                                     64  ...              64
# Christie                                                               15  ...              15
# ...                                                                   ...  ...             ...
# The Beaches                                                             4  ...               4
# The Danforth  East                                                      4  ...               4
# The Danforth West, Riverdale                                           42  ...              42
# Toronto Dominion Centre, Design Exchange                              100  ...             100
# University of Toronto, Harbord                                         35  ...              35
#
# [39 rows x 6 columns]

# %% [markdown]
# Number of unique categories of venues

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 213 uniques categories.

# %% [markdown]
# Encoding of data for clustering

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']
# move it to first position
toronto_onehot.insert(0, 'Neighborhood', toronto_onehot.pop('Neighborhood'))

del toronto_venues

print('Size of one-hot encoded dataframe is:', toronto_onehot.shape)

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

del toronto_onehot

print('Size of grouped encoded dataframe is:', toronto_grouped.shape)
toronto_grouped
# Out:
# Size of one-hot encoded dataframe is: (1499, 213)
# Size of grouped encoded dataframe is: (39, 213)
#                                          Neighborhood  ...  Yoga Studio
# 0                                         Berczy Park  ...     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place  ...     0.000000
# 2   CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 3                                  Central Bay Street  ...     0.015625
# 4                                            Christie  ...     0.000000
# ..                                                ...  ...          ...
# 34                                        The Beaches  ...     0.000000
# 35                                 The Danforth  East  ...     0.000000
# 36                       The Danforth West, Riverdale  ...     0.023810
# 37           Toronto Dominion Centre, Design Exchange  ...     0.000000
# 38                     University of Toronto, Harbord  ...     0.000000
#
# [39 rows x 213 columns]

# %% [markdown]
# Print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# ----Berczy Park----
#             venue  freq
# 0  Sandwich Place  0.06
# 1          Bakery  0.06
# 2    Cocktail Bar  0.06
# 3     Coffee Shop  0.06
# 4        Beer Bar  0.04
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0  Sandwich Place  0.09
# 1            Café  0.09
# 2          Bakery  0.09
# 3     Coffee Shop  0.09
# 4  Breakfast Spot  0.09
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0   Airport Service  0.17
# 1    Airport Lounge  0.11
# 2  Airport Terminal  0.11
# 3  Sculpture Garden  0.06
# 4   Harbor / Marina  0.06
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.17
# 1       Sandwich Place  0.08
# 2     Sushi Restaurant  0.06
# 3   Italian Restaurant  0.06
# 4  Japanese Restaurant  0.05
#
#
# ----Christie----
#                 venue  freq
# 0       Grocery Store  0.27
# 1                Café  0.20
# 2                Park  0.13
# 3          Baby Store  0.07
# 4  Athletics & Sports  0.07
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0     Sushi Restaurant  0.09
# 1  Japanese Restaurant  0.08
# 2           Restaurant  0.05
# 3          Coffee Shop  0.05
# 4              Gay Bar  0.05
#
#
# ----Commerce Court, Victoria Hotel----
#             venue  freq
# 0     Coffee Shop  0.12
# 1            Café  0.07
# 2  Sandwich Place  0.07
# 3           Hotel  0.06
# 4      Restaurant  0.05
#
#
# ----Davisville----
#               venue  freq
# 0       Pizza Place  0.11
# 1    Sandwich Place  0.07
# 2               Gym  0.07
# 3      Dessert Shop  0.07
# 4  Sushi Restaurant  0.07
#
#
# ----Davisville North----
#                   venue  freq
# 0  Gym / Fitness Center   0.1
# 1        Breakfast Spot   0.1
# 2                   Gym   0.1
# 3                 Hotel   0.1
# 4     Food & Drink Shop   0.1
#
#
# ----Dufferin, Dovercourt Village----
#          venue  freq
# 0     Pharmacy  0.07
# 1      Brewery  0.07
# 2         Café  0.07
# 3          Bar  0.07
# 4  Music Venue  0.07
#
#
# ----Enclave of M4L----
#            venue  freq
# 0    Yoga Studio  0.07
# 1  Garden Center  0.07
# 2    Pizza Place  0.07
# 3           Park  0.07
# 4     Restaurant  0.07
#
#
# ----Enclave of M5E----
#                  venue  freq
# 0       Sandwich Place  0.07
# 1          Coffee Shop  0.06
# 2  Japanese Restaurant  0.04
# 3                 Bank  0.04
# 4                 Café  0.04
#
#
# ----First Canadian Place, Underground city----
#             venue  freq
# 0     Coffee Shop  0.13
# 1            Café  0.08
# 2  Sandwich Place  0.08
# 3           Hotel  0.05
# 4             Gym  0.04
#
#
# ----Forest Hill North & West----
#               venue  freq
# 0              Park  0.25
# 1             Trail  0.25
# 2     Jewelry Store  0.25
# 3  Sushi Restaurant  0.25
# 4    Adult Boutique  0.00
#
#
# ----Garden District, Ryerson----
#             venue  freq
# 0     Coffee Shop  0.13
# 1  Sandwich Place  0.07
# 2  Clothing Store  0.07
# 3            Café  0.06
# 4            Bank  0.03
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#             venue  freq
# 0     Coffee Shop  0.18
# 1            Café  0.04
# 2           Hotel  0.04
# 3     Pizza Place  0.03
# 4  Scenic Lookout  0.03
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0  Mexican Restaurant  0.11
# 1                Café  0.11
# 2                 Bar  0.11
# 3           Speakeasy  0.06
# 4               Diner  0.06
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0                  Park  0.11
# 1  Fast Food Restaurant  0.11
# 2            Playground  0.05
# 3            Restaurant  0.05
# 4            Board Shop  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0                           Café  0.09
# 1                    Coffee Shop  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3          Vietnamese Restaurant  0.04
# 4                    Gaming Cafe  0.04
#
#
# ----Lawrence Park----
#                   venue  freq
# 0  Gym / Fitness Center  0.25
# 1              Bus Line  0.25
# 2                  Park  0.25
# 3           Swim School  0.25
# 4           Men's Store  0.00
#
#
# ----Little Portugal, Trinity----
#                            venue  freq
# 0                            Bar  0.07
# 1          Vietnamese Restaurant  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3                           Café  0.05
# 4                    Coffee Shop  0.05
#
#
# ----Moore Park, Summerhill East----
#                       venue  freq
# 0              Tennis Court   0.5
# 1                Restaurant   0.5
# 2            Adult Boutique   0.0
# 3  Mediterranean Restaurant   0.0
# 4               Men's Store   0.0
#
#
# ----North Toronto West----
#                   venue  freq
# 0        Clothing Store  0.20
# 1           Coffee Shop  0.13
# 2  Gym / Fitness Center  0.07
# 3   Sporting Goods Shop  0.07
# 4                  Park  0.07
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0                  Coffee Shop  0.18
# 1                      Dog Run  0.09
# 2               Breakfast Spot  0.09
# 3             Cuban Restaurant  0.09
# 4  Eastern European Restaurant  0.09
#
#
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.16
# 1         Café  0.07
# 2          Pub  0.07
# 3       Bakery  0.07
# 4         Park  0.07
#
#
# ----Richmond, Adelaide, King----
#             venue  freq
# 0     Coffee Shop  0.17
# 1            Café  0.06
# 2  Sandwich Place  0.05
# 3  Clothing Store  0.04
# 4             Gym  0.04
#
#
# ----Rosedale----
#             venue  freq
# 0            Park  0.50
# 1      Playground  0.25
# 2           Trail  0.25
# 3  Adult Boutique  0.00
# 4   Movie Theater  0.00
#
#
# ----Roselawn----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1                  Pool  0.25
# 2                Garden  0.25
# 3           Music Venue  0.25
# 4        Adult Boutique  0.00
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1    Sushi Restaurant  0.06
# 2         Pizza Place  0.06
# 3                 Pub  0.06
# 4  Italian Restaurant  0.06
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.05
# 2        Cocktail Bar  0.05
# 3                Café  0.05
# 4          Restaurant  0.04
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1                 Pub  0.06
# 2                Café  0.06
# 3          Restaurant  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Studio District----
#                        venue  freq
# 0                Coffee Shop  0.10
# 1                     Bakery  0.07
# 2                  Gastropub  0.07
# 3                       Café  0.07
# 4  Middle Eastern Restaurant  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#               venue  freq
# 0       Coffee Shop  0.18
# 1       Pizza Place  0.09
# 2        Bagel Shop  0.09
# 3              Bank  0.09
# 4  Sushi Restaurant  0.09
#
#
# ----The Annex, North Midtown, Yorkville----
#                venue  freq
# 0     Sandwich Place  0.18
# 1               Café  0.12
# 2        Coffee Shop  0.12
# 3        Pizza Place  0.06
# 4  Indian Restaurant  0.06
#
#
# ----The Beaches----
#                venue  freq
# 0        Coffee Shop  0.25
# 1  Health Food Store  0.25
# 2                Pub  0.25
# 3             Museum  0.00
# 4        Men's Store  0.00
#
#
# ----The Danforth  East----
#                venue  freq
# 0        Coffee Shop  0.25
# 1      Metro Station  0.25
# 2               Park  0.25
# 3  Convenience Store  0.25
# 4             Museum  0.00
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.24
# 1  Italian Restaurant  0.07
# 2         Coffee Shop  0.07
# 3    Sushi Restaurant  0.05
# 4      Ice Cream Shop  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#               venue  freq
# 0       Coffee Shop  0.13
# 1              Café  0.08
# 2             Hotel  0.06
# 3    Sandwich Place  0.05
# 4  Asian Restaurant  0.04
#
#
# ----University of Toronto, Harbord----
#             venue  freq
# 0            Café  0.14
# 1     Coffee Shop  0.11
# 2  Sandwich Place  0.09
# 3          Bakery  0.06
# 4             Bar  0.06

# %% [markdown]
# Run k-means clustering on encoded data without 'Neighborhood' column

# %%
from sklearn.cluster import KMeans

# %%
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', axis=1)

kclusters = 5
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

del toronto_grouped_clustering

toronto_grouped.insert(1, 'Cluster', kmeans.labels_)
toronto_grouped
# Out:
#                                          Neighborhood  ...  Yoga Studio
# 0                                         Berczy Park  ...     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place  ...     0.000000
# 2   CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 3                                  Central Bay Street  ...     0.015625
# 4                                            Christie  ...     0.000000
# ..                                                ...  ...          ...
# 34                                        The Beaches  ...     0.000000
# 35                                 The Danforth  East  ...     0.000000
# 36                       The Danforth West, Riverdale  ...     0.023810
# 37           Toronto Dominion Centre, Design Exchange  ...     0.000000
# 38                     University of Toronto, Harbord  ...     0.000000
#
# [39 rows x 214 columns]

# %% [markdown]
# Merge the results of clustering with the main dataframe

# %%
df = pd.merge(df, toronto_grouped[['Neighborhood',	'Cluster']], on='Neighborhood')
df
# Out:
#    PostalCode                 Borough  ...  Longitude  Cluster
# 0         M5A        Downtown Toronto  ... -79.360636        0
# 1         M5B        Downtown Toronto  ... -79.378937        0
# 2         M5C        Downtown Toronto  ... -79.375418        0
# 3         M4E            East Toronto  ... -79.293031        2
# 4         M5E        Downtown Toronto  ... -79.373306        0
# ..        ...                     ...  ...        ...      ...
# 34        M5W  Downtown Toronto Stn A  ... -79.374846        0
# 35        M4X        Downtown Toronto  ... -79.367675        0
# 36        M5X        Downtown Toronto  ... -79.382280        0
# 37        M4Y        Downtown Toronto  ... -79.383160        0
# 38        M7Y   East Toronto Business  ... -79.321558        0
#
# [39 rows x 6 columns]

# %% [markdown]
# Visualization of the results of clustering on the map

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df['Latitude'], df['Longitude'], df['Neighborhood'], df['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_4a4128c973c146a48a46034b9a4de7d9%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4a4128c973c146a48a46034b9a4de7d9%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_4a4128c973c146a48a46034b9a4de7d9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_4a4128c973c146a48a46034b9a4de7d9%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_93a0ca9c625b4ce19767c345a36d83ad%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# This is a saved screenshot of the above result for sharing on github
# ![toronto clusters](https://raw.githubusercontent.com/ibikinoradio/Coursera_Capstone/main/toronto_clusters.jpg)

# %% [markdown]
# ### Print 5 most common venues for up to 5 (less than 5 if cluster is smaller) neighbourhoods in Cluster 1

# %%
# Get rid of 'Cluster' column in toronto_grouped dataframe
toronto_grouped.drop('Cluster', axis=1, inplace=True)

# %%
cluster_idx = 0
num_top_venues = 5
num_neighbourhoods = 5

print('Cluster:', cluster_idx+1)

for i, hood in enumerate(df[df['Cluster']==cluster_idx]['Neighborhood']):

    if i == num_neighbourhoods:
        break

    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# Cluster: 1
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.16
# 1         Café  0.07
# 2          Pub  0.07
# 3       Bakery  0.07
# 4         Park  0.07
#
#
# ----Garden District, Ryerson----
#             venue  freq
# 0     Coffee Shop  0.13
# 1  Sandwich Place  0.07
# 2  Clothing Store  0.07
# 3            Café  0.06
# 4            Bank  0.03
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.05
# 2        Cocktail Bar  0.05
# 3                Café  0.05
# 4          Restaurant  0.04
#
#
# ----Berczy Park----
#             venue  freq
# 0  Sandwich Place  0.06
# 1          Bakery  0.06
# 2    Cocktail Bar  0.06
# 3     Coffee Shop  0.06
# 4        Beer Bar  0.04
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.17
# 1       Sandwich Place  0.08
# 2     Sushi Restaurant  0.06
# 3   Italian Restaurant  0.06
# 4  Japanese Restaurant  0.05

# %% [markdown]
# ### Print 5 most common venues for up to 5 (less than 5 if cluster is smaller) neighbourhoods in Cluster 2

# %%
cluster_idx = 1
num_top_venues = 5
num_neighbourhoods = 5

print('Cluster:', cluster_idx+1)

for i, hood in enumerate(df[df['Cluster']==cluster_idx]['Neighborhood']):

    if i == num_neighbourhoods:
        break

    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# Cluster: 2
# ----Moore Park, Summerhill East----
#                       venue  freq
# 0              Tennis Court   0.5
# 1                Restaurant   0.5
# 2            Adult Boutique   0.0
# 3  Mediterranean Restaurant   0.0
# 4               Men's Store   0.0

# %% [markdown]
# ### Print 5 most common venues for up to 5 (less than 5 if cluster is smaller) neighbourhoods in Cluster 3

# %%
cluster_idx = 2
num_top_venues = 5
num_neighbourhoods = 5

print('Cluster:', cluster_idx+1)

for i, hood in enumerate(df[df['Cluster']==cluster_idx]['Neighborhood']):

    if i == num_neighbourhoods:
        break

    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# Cluster: 3
# ----The Beaches----
#                venue  freq
# 0        Coffee Shop  0.25
# 1  Health Food Store  0.25
# 2                Pub  0.25
# 3             Museum  0.00
# 4        Men's Store  0.00

# %% [markdown]
# ### Print 5 most common venues for up to 5 (less than 5 if cluster is smaller) neighbourhoods in Cluster 4

# %%
cluster_idx = 3
num_top_venues = 5
num_neighbourhoods = 5

print('Cluster:', cluster_idx+1)

for i, hood in enumerate(df[df['Cluster']==cluster_idx]['Neighborhood']):

    if i == num_neighbourhoods:
        break

    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# Cluster: 4
# ----Forest Hill North & West----
#               venue  freq
# 0              Park  0.25
# 1             Trail  0.25
# 2     Jewelry Store  0.25
# 3  Sushi Restaurant  0.25
# 4    Adult Boutique  0.00
#
#
# ----Rosedale----
#             venue  freq
# 0            Park  0.50
# 1      Playground  0.25
# 2           Trail  0.25
# 3  Adult Boutique  0.00
# 4   Movie Theater  0.00

# %% [markdown]
# ### Print 5 most common venues for up to 5 (less than 5 if cluster is smaller) neighbourhoods in Cluster 5

# %%
cluster_idx = 4
num_top_venues = 5
num_neighbourhoods = 5

print('Cluster:', cluster_idx+1)

for i, hood in enumerate(df[df['Cluster']==cluster_idx]['Neighborhood']):

    if i == num_neighbourhoods:
        break

    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

del temp
# Out:
# Cluster: 5
# ----Roselawn----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1                  Pool  0.25
# 2                Garden  0.25
# 3           Music Venue  0.25
# 4        Adult Boutique  0.00
